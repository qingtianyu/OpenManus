# %%
# %pip install 'vanna[chromadb,openai,mysql]'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.8 MB/s eta 0:00:00
# ...

# %%
from vanna.openai import OpenAI_Chat
from openai import OpenAI
from vanna.chromadb import ChromaDB_VectorStore

# %%
OPENAI_BASE_URL="https://closeproxy.unidtai.com/v1"
OPENAI_API_KEY="sk-aRUVCBaoLTtfKSfX573c06D3779a41D4B26b00F11dF9Eb37"
OPENAI_MODEL="gpt-4o"

# %%
class MyVanna(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI.__init__(self, client = OpenAI())

# %%
vn = MyVanna(config={'api_key': 'sk-aRUVCBaoLTtfKSfX573c06D3779a41D4B26b00F11dF9Eb37', 'model': 'gpt-4o', 'api_base': 'https://closeproxy.unidtai.com/v1'})
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# <ipython-input-29-fd8ff50f5c33> in <cell line: 0>()
# ----> 1 vn = MyVanna(config={'api_key': 'sk-aRUVCBaoLTtfKSfX573c06D3779a41D4B26b00F11dF9Eb37', 'model': 'gpt-4o', 'api_base': 'https://closeproxy.unidtai.com/v1'})
#
# <ipython-input-28-cade385dff6a> in __init__(self, config)
#       2     def __init__(self, config=None):
#       3         ChromaDB_VectorStore.__init__(self, config=config)
# ----> 4         OpenAI.__init__(self, client = OpenAI())
#
# /usr/local/lib/python3.11/dist-packages/openai/_client.py in __init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     112             api_key = os.environ.get("OPENAI_API_KEY")
#     113         if api_key is None:
# --> 114             raise OpenAIError(
# ...

# %%
vn.connect_to_sqlite('https://vanna.ai/Chinook.sqlite')
vn.ask("What are the top 10 albums by sales?")
# Out:
# SQL Prompt: [{'role': 'system', 'content': "You are a SQLite expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. ===Response Guidelines \n1. If the provided context is sufficient, please generate a valid SQL query without any explanations for the question. \n2. If the provided context is almost sufficient but requires knowledge of a specific string in a particular column, please generate an intermediate SQL query to find the distinct strings in that column. Prepend the query with a comment saying intermediate_sql \n3. If the provided context is insufficient, please explain why it can't be generated. \n4. Please use the most relevant table(s). \n5. If the question has been asked and answered before, please repeat the answer exactly as it was given before. \n6. Ensure that the output SQL is SQLite-compliant and executable, and free of syntax errors. \n"}, 
# ...

# %%
from vanna.flask import VannaFlaskApp
VannaFlaskApp(vn).run()
# Out:
# Google Colab doesn't support running websocket servers. Disabling debug mode.
# ...
# Try `serve_kernel_port_as_iframe` instead.
# Your app is running at:
# https://8084-m-s-oqkyftbulvh3-b.us-central1-1.prod.colab.dev
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: off

# %% [markdown]
# ## Here's what you'll get
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)
